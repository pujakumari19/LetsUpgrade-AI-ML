# %% [markdown]
# # Assignment day 7

# %% [markdown]
# ## HR data analysis for attrition

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('general_data.csv')
df
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
df.shape
# Out:
# (4410, 24)

# %%
#As there is no relationship between attrition and employeeid so we can remove it
df.drop(columns='EmployeeID',inplace=True)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'Gender', 'JobLevel',
#        'JobRole', 'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked',
#        'Over18', 'PercentSalaryHike', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# Gender                      object
# JobLevel                     int64
# JobRole                     object
# MaritalStatus               object
# MonthlyIncome                int64
# NumCompaniesWorked         float64
# Over18                      object
# PercentSalaryHike            int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears          float64
# TrainingTimesLastYear        int64
# YearsAtCompany               int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# Over18                      0
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# EmployeeCount              0
# Gender                     0
# JobLevel                   0
# JobRole                    0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# Over18                     0
# PercentSalaryHike          0
# StandardHours              0
# StockOptionLevel           0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# EmployeeCount              0
# Gender                     0
# JobLevel                   0
# JobRole                    0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# Over18                     0
# PercentSalaryHike          0
# StandardHours              0
# StockOptionLevel           0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# dtype: int64

# %%
df.describe()
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount     JobLevel  \
# count  4382.000000       4382.000000  4382.000000         4382.0  4382.000000
# mean     36.933364          9.198996     2.912369            1.0     2.063898
# std       9.137272          8.105396     1.024728            0.0     1.106115
# min      18.000000          1.000000     1.000000            1.0     1.000000
# 25%      30.000000          2.000000     2.000000            1.0     1.000000
# 50%      36.000000          7.000000     3.000000            1.0     2.000000
# 75%      43.000000         14.000000     4.000000            1.0     3.000000
# max      60.000000         29.000000     5.000000            1.0     5.000000
#
#        MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  StandardHours  \
# count    4382.000000         4382.000000        4382.000000         4382.0
# mean    65061.702419            2.693291          15.210634            8.0
# ...

# %%
df.describe().columns
# Out:
# Index(['Age', 'DistanceFromHome', 'Education', 'EmployeeCount', 'JobLevel',
#        'MonthlyIncome', 'NumCompaniesWorked', 'PercentSalaryHike',
#        'StandardHours', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'YearsAtCompany', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
all_countinous_columns = ['Age', 'DistanceFromHome', 'EmployeeCount',
       'MonthlyIncome', 'NumCompaniesWorked', 'PercentSalaryHike',
       'StandardHours', 'StockOptionLevel', 'TotalWorkingYears',
       'TrainingTimesLastYear', 'YearsAtCompany', 'YearsSinceLastPromotion',
       'YearsWithCurrManager']

for one_countinous_column in all_countinous_columns:
    print('Box Plot For ',one_countinous_column)
    plt.boxplot(df[one_countinous_column])
    plt.show()
# Out:
# Box Plot For  Age
# Box Plot For  DistanceFromHome
# Box Plot For  EmployeeCount
# Box Plot For  MonthlyIncome
# Box Plot For  NumCompaniesWorked
# Box Plot For  PercentSalaryHike
# Box Plot For  StandardHours
# Box Plot For  StockOptionLevel
# Box Plot For  TotalWorkingYears
# Box Plot For  TrainingTimesLastYear
# Box Plot For  YearsAtCompany
# Box Plot For  YearsSinceLastPromotion
# Box Plot For  YearsWithCurrManager

# %% [markdown]
# ### As we can see there is no outlier for: Age, Distace From Home, Employee Count, Percent Salary Hike, Standerd Hourswe can also see that there are few outliers in MonthlyIncome, NumCompaniesWorked, Stock OptionLevel, TotalWorkingYears, TrainingTimes Last Year, Years At Company, Years SinceLast Promotion and YearWithCurrent Manager

# %%
df=pd.get_dummies(df,drop_first=True)
df
# Out:
#       Age  DistanceFromHome  Education  EmployeeCount  JobLevel  \
# 0      51                 6          2              1         1
# 1      31                10          1              1         1
# 2      32                17          4              1         4
# 3      38                 2          5              1         3
# 4      32                10          1              1         1
# ...   ...               ...        ...            ...       ...
# 4404   29                 4          3              1         2
# 4405   42                 5          4              1         1
# 4406   29                 2          4              1         1
# 4407   25                25          2              1         2
# 4408   42                18          2              1         1
#
#       MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  StandardHours  \
# 0            131160                 1.0                 11              8
# ...

# %%
df.columns
# Out:
# Index(['Age', 'DistanceFromHome', 'Education', 'EmployeeCount', 'JobLevel',
#        'MonthlyIncome', 'NumCompaniesWorked', 'PercentSalaryHike',
#        'StandardHours', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'YearsAtCompany', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Attrition_Yes',
#        'BusinessTravel_Travel_Frequently', 'BusinessTravel_Travel_Rarely',
#        'Department_Research & Development', 'Department_Sales',
#        'EducationField_Life Sciences', 'EducationField_Marketing',
#        'EducationField_Medical', 'EducationField_Other',
#        'EducationField_Technical Degree', 'Gender_Male',
#        'JobRole_Human Resources', 'JobRole_Laboratory Technician',
#        'JobRole_Manager', 'JobRole_Manufacturing Director',
#        'JobRole_Research Director', 'JobRole_Research Scientist',
#        'JobRole_Sales Executive', 'JobRole_Sales Representative',
#        'MaritalStatus_Married', 'MaritalStatus_Single'],
# ...

# %%
df.corr()
# Out:
#                                         Age  DistanceFromHome  Education  \
# Age                                1.000000          0.007376  -0.033900
# DistanceFromHome                   0.007376          1.000000  -0.007491
# Education                         -0.033900         -0.007491   1.000000
# EmployeeCount                           NaN               NaN        NaN
# JobLevel                          -0.001137         -0.039990   0.045822
# MonthlyIncome                     -0.045163         -0.022757   0.007289
# NumCompaniesWorked                 0.299527         -0.014449  -0.016210
# PercentSalaryHike                 -0.032561          0.037720  -0.041054
# StandardHours                           NaN               NaN        NaN
# StockOptionLevel                  -0.031504          0.009353   0.002386
# TotalWorkingYears                  0.680037          0.009574  -0.009228
# TrainingTimesLastYear             -0.028962         -0.008957   0.009939
# ...

# %%
df.corr()['Attrition_Yes']
# Out:
# Age                                 -0.158399
# DistanceFromHome                    -0.009449
# Education                           -0.017106
# EmployeeCount                             NaN
# JobLevel                            -0.012382
# MonthlyIncome                       -0.030160
# NumCompaniesWorked                   0.042831
# PercentSalaryHike                    0.033153
# StandardHours                             NaN
# StockOptionLevel                    -0.008164
# TotalWorkingYears                   -0.169670
# TrainingTimesLastYear               -0.047586
# YearsAtCompany                      -0.133003
# YearsSinceLastPromotion             -0.031423
# YearsWithCurrManager                -0.154692
# Attrition_Yes                        1.000000
# BusinessTravel_Travel_Frequently     0.113231
# BusinessTravel_Travel_Rarely        -0.048146
# Department_Research & Development   -0.015583
# Department_Sales                    -0.017531
# ...

# %%
df.var()
# Out:
# Age                                  8.348974e+01
# DistanceFromHome                     6.569744e+01
# Education                            1.050068e+00
# EmployeeCount                        0.000000e+00
# JobLevel                             1.223490e+00
# MonthlyIncome                        2.222397e+09
# NumCompaniesWorked                   6.239165e+00
# PercentSalaryHike                    1.341762e+01
# StandardHours                        0.000000e+00
# StockOptionLevel                     7.265814e-01
# TotalWorkingYears                    6.061739e+01
# TrainingTimesLastYear                1.662558e+00
# YearsAtCompany                       3.756894e+01
# YearsSinceLastPromotion              1.040059e+01
# YearsWithCurrManager                 1.274257e+01
# Attrition_Yes                        1.350321e-01
# BusinessTravel_Travel_Frequently     1.528594e-01
# BusinessTravel_Travel_Rarely         2.061596e-01
# Department_Research & Development    2.263938e-01
# ...

# %%
df.median()
# Out:
# Age                                     36.0
# DistanceFromHome                         7.0
# Education                                3.0
# EmployeeCount                            1.0
# JobLevel                                 2.0
# MonthlyIncome                        49190.0
# NumCompaniesWorked                       2.0
# PercentSalaryHike                       14.0
# StandardHours                            8.0
# StockOptionLevel                         1.0
# TotalWorkingYears                       10.0
# TrainingTimesLastYear                    3.0
# YearsAtCompany                           5.0
# YearsSinceLastPromotion                  1.0
# YearsWithCurrManager                     3.0
# Attrition_Yes                            0.0
# BusinessTravel_Travel_Frequently         0.0
# BusinessTravel_Travel_Rarely             1.0
# Department_Research & Development        1.0
# Department_Sales                         0.0
# EducationField_Life Sciences             0.0
# ...

# %%
df.mode()
# Out:
#    Age  DistanceFromHome  Education  EmployeeCount  JobLevel  MonthlyIncome  \
# 0   35                 2          3              1         1          23420
#
#    NumCompaniesWorked  PercentSalaryHike  StandardHours  StockOptionLevel  \
# 0                 1.0                 11              8                 0
#
#    ...  JobRole_Human Resources  JobRole_Laboratory Technician  \
# 0  ...                        0                              0
#
#    JobRole_Manager  JobRole_Manufacturing Director  JobRole_Research Director  \
# 0                0                               0                          0
#
#    JobRole_Research Scientist  JobRole_Sales Executive  \
# 0                           0                        0
#
#    JobRole_Sales Representative  MaritalStatus_Married  MaritalStatus_Single
# 0                             0                      0                     0
#
# [1 rows x 36 columns]

# %%
df.skew()
# Out:
# Age                                  0.413048
# DistanceFromHome                     0.955517
# Education                           -0.288977
# EmployeeCount                        0.000000
# JobLevel                             1.021797
# MonthlyIncome                        1.367457
# NumCompaniesWorked                   1.029174
# PercentSalaryHike                    0.819510
# StandardHours                        0.000000
# StockOptionLevel                     0.967263
# TotalWorkingYears                    1.115419
# TrainingTimesLastYear                0.551818
# YearsAtCompany                       1.764619
# YearsSinceLastPromotion              1.980992
# YearsWithCurrManager                 0.834277
# Attrition_Yes                        1.846529
# BusinessTravel_Travel_Frequently     1.595367
# BusinessTravel_Travel_Rarely        -0.923202
# Department_Research & Development   -0.646820
# Department_Sales                     0.854995
# ...

# %%
df.kurt()
# Out:
# Age                                  -0.409517
# DistanceFromHome                     -0.230691
# Education                            -0.565008
# EmployeeCount                         0.000000
# JobLevel                              0.388189
# MonthlyIncome                         0.990836
# NumCompaniesWorked                    0.014307
# PercentSalaryHike                    -0.306951
# StandardHours                         0.000000
# StockOptionLevel                      0.356755
# TotalWorkingYears                     0.909316
# TrainingTimesLastYear                 0.494215
# YearsAtCompany                        3.930726
# YearsSinceLastPromotion               3.592162
# YearsWithCurrManager                  0.170703
# Attrition_Yes                         1.410313
# BusinessTravel_Travel_Frequently      0.545443
# BusinessTravel_Travel_Rarely         -1.148222
# Department_Research & Development    -1.582346
# Department_Sales                     -1.269563
# ...

# %% [markdown]
# ### Inference

# %% [markdown]
# 1.Employee who travel Frequently and Whoes Martials Status is single is more like to leave the company
#
# 2.Employee with high age is less likly leave the compnay
#
# 3.Employee Who is working With Large number of years with his manager is less likely to leave the company
